# %%
import numpy as np
import pandas as pd
import os

# %%
dir = 'C:\\Users\\pengu\\Downloads\\workspace\\Github\\Keiba\\GetCSV'
dir += '\\keiba2015.csv'

# %%
df = pd.read_csv(dir, encoding='shift-jis')
del(df['popu'], df['date'], df['head_count'], df['race_name'], df['race'], df['Unnamed: 0'])

# %%
df['gender'] = df['gender'].replace(['牝', '牡'], [0, 1])
df['field'] = df['field'].replace([])

# %%
df
# Out:
#        age  c_weight  course field gender horse_name  j_weight jackie   odds  \
# 0        2      -2.0  芝1500m    札幌      1     マカーオーン      54.0     勝浦    7.3
# 1        2      -4.0  芝1500m    札幌      1  ショウザイシンホー      54.0     三浦    8.2
# 2        2       0.0  芝1500m    札幌      1   インジャスティス      54.0    ルメー    4.5
# 3        2       0.0  芝1500m    札幌      1  ルミナスエレメント      54.0     福永    2.8
# 4        2       4.0  芝1500m    札幌      0    ジュアンマリエ      51.0    ▲加藤    3.8
# 5        2       0.0  芝1500m    札幌      1     コスモベガス      54.0      黛   14.7
# 6        2      -6.0  芝1500m    札幌      0   ネクストヒロイン      54.0     嶋田   94.4
# 7        2       0.0  芝1500m    札幌      1  マイネルアクティヴ      54.0     丹内  142.9
# 8        2      -6.0  芝1500m    札幌      1    サフランナイト      54.0     松岡  235.2
# 9        2       0.0  芝1500m    札幌      0    ジュンノキボウ      54.0    田中博   90.1
# 10       3      -2.0  ダ1000m    札幌      0    シゲルハナガサ      54.0     藤田    8.0
# ...
